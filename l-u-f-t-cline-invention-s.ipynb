# %% [markdown]
# <a href="https://www.kaggle.com/code/carldeanclinesr/l-u-f-t-cline-invention-s?scriptVersionId=237130628" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/winsat-data-sets/f17_20241220v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250425v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241212v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241223v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070319v7.unc
# /kaggle/input/winsat-data-sets/f17_20250410v7
# /kaggle/input/winsat-data-sets/f18_20250408v8
# /kaggle/input/winsat-data-sets/f18_20250406v8
# /kaggle/input/winsat-data-sets/f17_20070406v7.unc
# /kaggle/input/winsat-data-sets/f17_20070409v7.unc
# /kaggle/input/winsat-data-sets/f17_20241224v7
# /kaggle/input/winsat-data-sets/f17_20070329v7.unc
# /kaggle/input/winsat-data-sets/f17_20250426v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250422v7
# /kaggle/input/winsat-data-sets/wsat_20030705v7.0.1
# /kaggle/input/winsat-data-sets/wsat_20030726v7.0.1
# /kaggle/input/winsat-data-sets/f17_20070320v7.unc
# /kaggle/input/winsat-data-sets/f17_20070302v7.unc
# /kaggle/input/winsat-data-sets/f17_20250414v7
# /kaggle/input/winsat-data-sets/f17_20250421v7
# /kaggle/input/winsat-data-sets/f17_20241230v7
# /kaggle/input/winsat-data-sets/f18_20250421v8
# /kaggle/input/winsat-data-sets/f17_20250417v7
# /kaggle/input/winsat-data-sets/f17_20250401v7
# /kaggle/input/winsat-data-sets/f17_20241203v7
# /kaggle/input/winsat-data-sets/f18_20250428v8
# /kaggle/input/winsat-data-sets/f17_20070322v7.unc
# /kaggle/input/winsat-data-sets/wsat_20030301v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241231v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070307v7.unc
# /kaggle/input/winsat-data-sets/f17_20241201v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250427rt
# /kaggle/input/winsat-data-sets/f17_20250406v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250407v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250402v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241216v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030412v7.0.1
# /kaggle/input/winsat-data-sets/f18_20250420v8
# /kaggle/input/winsat-data-sets/f17_20241214v7
# /kaggle/input/winsat-data-sets/f17_20241205v7
# /kaggle/input/winsat-data-sets/f17_20241222v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070313v7.unc
# /kaggle/input/winsat-data-sets/f17_20070328v7.unc
# /kaggle/input/winsat-data-sets/f17_20250412v7
# /kaggle/input/winsat-data-sets/f17_20070306v7.unc
# /kaggle/input/winsat-data-sets/f17_20241228v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250417v8
# /kaggle/input/winsat-data-sets/f17_20070330v7.unc
# /kaggle/input/winsat-data-sets/wsat_20030315v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250411v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250403v8
# /kaggle/input/winsat-data-sets/f17_20070324v7.unc
# /kaggle/input/winsat-data-sets/f17_20070323v7.unc
# /kaggle/input/winsat-data-sets/f17_20250427v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070316v7.unc
# /kaggle/input/winsat-data-sets/f17_20241227v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030322v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241228v7
# /kaggle/input/winsat-data-sets/wsat_20030531v7.0.1
# /kaggle/input/winsat-data-sets/f18_20250403v8_d3d
# /kaggle/input/winsat-data-sets/f17_20070304v7.unc
# /kaggle/input/winsat-data-sets/f17_20250409v7
# /kaggle/input/winsat-data-sets/f17_20241218v7
# /kaggle/input/winsat-data-sets/f17_20241207v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250424v7
# /kaggle/input/winsat-data-sets/f17_20070301v7.unc
# /kaggle/input/winsat-data-sets/f17_20241205v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250427v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250409v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070410v7.unc
# /kaggle/input/winsat-data-sets/wsat_20030524v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250402v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030621v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250427rt_d3d
# /kaggle/input/winsat-data-sets/wsat_20030503v7.0.1
# /kaggle/input/winsat-data-sets/f18_20250422v8
# /kaggle/input/winsat-data-sets/f18_20250412v8_d3d
# /kaggle/input/winsat-data-sets/f18_20250423v8
# /kaggle/input/winsat-data-sets/f17_20241217v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070314v7.unc
# /kaggle/input/winsat-data-sets/f17_20241223v7
# /kaggle/input/winsat-data-sets/f18_20250404v8_d3d
# /kaggle/input/winsat-data-sets/wsat_20030419v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241230v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241208v7
# /kaggle/input/winsat-data-sets/f17_20250426v7
# /kaggle/input/winsat-data-sets/wsat_20030426v7.0.1
# /kaggle/input/winsat-data-sets/wsat_20030222v7.0.1
# /kaggle/input/winsat-data-sets/f18_20250410v8
# /kaggle/input/winsat-data-sets/f17_20250404v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030215v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241217v7
# /kaggle/input/winsat-data-sets/f18_20250425v8
# /kaggle/input/winsat-data-sets/f17_20241213v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070321v7.unc
# /kaggle/input/winsat-data-sets/f17_20241211v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070403v7.unc
# /kaggle/input/winsat-data-sets/wsat_20030517v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250419v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250411v8
# /kaggle/input/winsat-data-sets/f17_20250411v7
# /kaggle/input/winsat-data-sets/f18_20250406v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241225v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241202v7
# /kaggle/input/winsat-data-sets/f18_20250415v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241210v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250416v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241213v7
# /kaggle/input/winsat-data-sets/f17_20241220v7
# /kaggle/input/winsat-data-sets/f17_20250426rt_d3d
# /kaggle/input/winsat-data-sets/f18_20250405v8
# /kaggle/input/winsat-data-sets/wsat_20030712v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241222v7
# /kaggle/input/winsat-data-sets/f18_20250404v8
# /kaggle/input/winsat-data-sets/f18_20250422v8_d3d
# /kaggle/input/winsat-data-sets/f17_20070402v7.unc
# /kaggle/input/winsat-data-sets/f18_20250426v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250420v7
# /kaggle/input/winsat-data-sets/f17_20241227v7
# /kaggle/input/winsat-data-sets/f17_20250408v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070317v7.unc
# /kaggle/input/winsat-data-sets/f17_20250428v7
# /kaggle/input/winsat-data-sets/f17_20241212v7
# /kaggle/input/winsat-data-sets/f17_20241203v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250407v8
# /kaggle/input/winsat-data-sets/f17_20241209v7
# /kaggle/input/winsat-data-sets/f17_20250427v7
# /kaggle/input/winsat-data-sets/f18_20250428v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241224v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250402v8
# /kaggle/input/winsat-data-sets/f17_20250403v7
# /kaggle/input/winsat-data-sets/f17_20241202v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070407v7.unc
# /kaggle/input/winsat-data-sets/f18_20250426v8
# /kaggle/input/winsat-data-sets/f17_20250418v7
# /kaggle/input/winsat-data-sets/f17_20250420v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250413v7
# /kaggle/input/winsat-data-sets/f17_20241210v7
# /kaggle/input/winsat-data-sets/f18_20250412v8
# /kaggle/input/winsat-data-sets/f17_20241201v7
# /kaggle/input/winsat-data-sets/f17_20250421v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250422v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250417v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241214v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250428rt
# /kaggle/input/winsat-data-sets/f17_20250423v7
# /kaggle/input/winsat-data-sets/f17_20241209v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250425v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241208v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030628v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250414v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070401v7.unc
# /kaggle/input/winsat-data-sets/f18_20250424v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241221v7
# /kaggle/input/winsat-data-sets/ws_v07r01_198801_202212.nc3.nc
# /kaggle/input/winsat-data-sets/f17_20241226v7
# /kaggle/input/winsat-data-sets/f17_20241215v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241211v7
# /kaggle/input/winsat-data-sets/f18_20250420v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241219v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030719v7.0.1
# /kaggle/input/winsat-data-sets/f17_20241216v7
# /kaggle/input/winsat-data-sets/f18_20250413v8
# /kaggle/input/winsat-data-sets/f17_20241219v7
# /kaggle/input/winsat-data-sets/wsat_20030308v7.0.1
# /kaggle/input/winsat-data-sets/f18_20250409v8_d3d
# /kaggle/input/winsat-data-sets/f18_20250419v8
# /kaggle/input/winsat-data-sets/f18_20250414v8_d3d
# /kaggle/input/winsat-data-sets/f17_20241206v7
# /kaggle/input/winsat-data-sets/f17_20241226v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250425v7
# /kaggle/input/winsat-data-sets/f18_20250427v8
# /kaggle/input/winsat-data-sets/wsat_20030329v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250402v7
# /kaggle/input/winsat-data-sets/f17_20250418v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250416v8
# /kaggle/input/winsat-data-sets/ws_v07r02_198801_20
# /kaggle/input/winsat-data-sets/f17_20070315v7.unc
# /kaggle/input/winsat-data-sets/wsat_20030614v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250416v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250401v8
# /kaggle/input/winsat-data-sets/f17_20070318v7.unc
# /kaggle/input/winsat-data-sets/f17_20070411v7.unc
# /kaggle/input/winsat-data-sets/f17_20250428rt_d3d
# /kaggle/input/winsat-data-sets/f17_202412v7
# /kaggle/input/winsat-data-sets/f18_20250411v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250404v7
# /kaggle/input/winsat-data-sets/f17_20250408v7
# /kaggle/input/winsat-data-sets/f17_20241206v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250405v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250406v7
# /kaggle/input/winsat-data-sets/f17_20241204v7_d3d
# /kaggle/input/winsat-data-sets/f17_20070408v7.unc
# /kaggle/input/winsat-data-sets/f17_20241207v7
# /kaggle/input/winsat-data-sets/f18_20250417v8_d3d
# /kaggle/input/winsat-data-sets/f17_20070331v7.unc
# /kaggle/input/winsat-data-sets/f17_20250424v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241231v7
# /kaggle/input/winsat-data-sets/f18_20250418v8
# /kaggle/input/winsat-data-sets/f18_20250401v8_d3d
# /kaggle/input/winsat-data-sets/f18_20250419v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250405v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250413v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250419v7
# /kaggle/input/winsat-data-sets/f17_20241215v7
# /kaggle/input/winsat-data-sets/f18_20250407v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250403v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241218v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250407v7
# /kaggle/input/winsat-data-sets/f18_20250408v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250410v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241204v7
# /kaggle/input/winsat-data-sets/f18_20250409v8
# /kaggle/input/winsat-data-sets/f17_20250426rt
# /kaggle/input/winsat-data-sets/f17_20241221v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250415v8
# /kaggle/input/winsat-data-sets/f17_20070326v7.unc
# /kaggle/input/winsat-data-sets/f17_20070327v7.unc
# /kaggle/input/winsat-data-sets/f17_20070305v7.unc
# /kaggle/input/winsat-data-sets/f17_20250412v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250421v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250415v7
# /kaggle/input/winsat-data-sets/f18_20250424v8
# /kaggle/input/winsat-data-sets/f18_20250413v8_d3d
# /kaggle/input/winsat-data-sets/wsat_20030405v7.0.1
# /kaggle/input/winsat-data-sets/f17_20070303v7.unc
# /kaggle/input/winsat-data-sets/f17_20241229v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030208v7.0.1
# /kaggle/input/winsat-data-sets/f17_20250423v7_d3d
# /kaggle/input/winsat-data-sets/f18_20250418v8_d3d
# /kaggle/input/winsat-data-sets/f17_20250415v7_d3d
# /kaggle/input/winsat-data-sets/wsat_20030510v7.0.1
# /kaggle/input/winsat-data-sets/f17_20070325v7.unc
# /kaggle/input/winsat-data-sets/f18_20250414v8
# /kaggle/input/winsat-data-sets/f17_20241225v7
# /kaggle/input/winsat-data-sets/f17_20250405v7
# /kaggle/input/winsat-data-sets/f17_20250401v7_d3d
# /kaggle/input/winsat-data-sets/f17_20241229v7
# /kaggle/input/winsat-data-sets/f17_20250428v7_d3d
# /kaggle/input/winsat-data-sets/f17_20250416v7
# /kaggle/input/winsat-data-sets/f17_20070405v7.unc
# /kaggle/input/winsat-data-sets/f18_20250423v8_d3d
# /kaggle/input/winsat-data-sets/wsat_20030607v7.0.1
# /kaggle/input/winsat-data-sets/f17_20070404v7.unc
# /kaggle/input/winsat-data-sets/f18_20250410v8_d3d
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_84416_HIP99427_0037.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/The LUFT DATA and PROBE04262025.txt
# /kaggle/input/luft-investigations-datasets-plus/HD073882_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_84066_HIP99560_0036.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/S5_WASP80b_transit_F322W2_fitpar.epf
# /kaggle/input/luft-investigations-datasets-plus/S3_WASP80b_transit_F322W2.5.ecf
# /kaggle/input/luft-investigations-datasets-plus/HD147888_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/CCOR1_1B_20250403T183025_V00_NC.fits
# /kaggle/input/luft-investigations-datasets-plus/S5_WASP80b_transit_F322W2.ecf
# /kaggle/input/luft-investigations-datasets-plus/HD038087_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/S2_WASP80b_transit_F322W2.3.ecf
# /kaggle/input/luft-investigations-datasets-plus/S1_WASP80b_eclipse_F322W2.ecf
# /kaggle/input/luft-investigations-datasets-plus/S5_WASP80b_eclipse_F322W2.8.ecf
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_84766_HIP99759_0038.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/S4_WASP80b_transit_F322W2.7.ecf
# /kaggle/input/luft-investigations-datasets-plus/Starlink.txt
# /kaggle/input/luft-investigations-datasets-plus/HD206267_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/S5_WASP80b_eclipse_F322W2_fitpar.epf
# /kaggle/input/luft-investigations-datasets-plus/CCOR1_1B_20250407T041525_V00_NC (1).fits
# /kaggle/input/luft-investigations-datasets-plus/HD203938_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/voyagersquest-metadata.txt
# /kaggle/input/luft-investigations-datasets-plus/HD207198_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/JADES-GS-z14-0-1d-spectrum.jpg
# /kaggle/input/luft-investigations-datasets-plus/S6_WASP80b_transit_F322W2.ecf
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_83371_HIP100670_0034.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/CCOR1_1B_20250407T041525_V00_NC.fits
# /kaggle/input/luft-investigations-datasets-plus/S4_WASP80b_eclipse_F322W2.6.ecf
# /kaggle/input/luft-investigations-datasets-plus/vg2_pws_wf_2006030708_v1.0.cdf
# /kaggle/input/luft-investigations-datasets-plus/S6_WASP80b_eclipse_F322W2.ecf
# /kaggle/input/luft-investigations-datasets-plus/R2022041906-MIRIM_FP1MIMF-26.fits
# /kaggle/input/luft-investigations-datasets-plus/HD014434_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/voyagersquest-metadata.json
# /kaggle/input/luft-investigations-datasets-plus/psp_L3_wispr_20241006T000019_V1_1221.fits
# /kaggle/input/luft-investigations-datasets-plus/HD216898_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/Groks file 2.txt
# /kaggle/input/luft-investigations-datasets-plus/S1_WASP80b_transit_F322W2.2.ecf
# /kaggle/input/luft-investigations-datasets-plus/CCOR1_1B_20250314T154525_V00_NC.fits
# /kaggle/input/luft-investigations-datasets-plus/S2_WASP80b_eclipse_F322W2.3.ecf
# /kaggle/input/luft-investigations-datasets-plus/HD152249_F322W2_fullSED.dat
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_83716_HIP99427_0035.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/starlink_44714_11_march2025_10_april 2025.csv
# /kaggle/input/luft-investigations-datasets-plus/s41586-024-07860-9.pdf
# /kaggle/input/luft-investigations-datasets-plus/spliced_blc0001020304050607_guppi_57752_83026_HIP99427_0033.gpuspec.0000.h5
# /kaggle/input/luft-investigations-datasets-plus/S3_WASP80b_eclipse_F322W2.4.ecf
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (77).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (88).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (2).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (87).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (26).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (8).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (9).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (11).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (54).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (79).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Groks File.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (94).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (21).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (60).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (92).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/spacecraft.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (12).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (19).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (32).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (20).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/The sphere Cline.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (43).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/GroK and Cline 2025.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (57).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (86).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (14).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/JADES-GS-z14-1_spec1D.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (65).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (91).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/grokandcline2025 our work.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (62).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (22).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (50).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (17).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (53).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (84).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/LUFT Dr.CLINE (91).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (34).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (6).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Grok and Captain ClineSr 03262025.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/grok and Cline3.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (95).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (8a).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (64).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (96).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (10).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (83).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (70).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/starlink_tle.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (33).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (71).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (56).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (27).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (35).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (38).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (61).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (85).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (68).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (48).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (41).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/JADES-GS-z14-0_spec1D.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (67).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/March 28th 2025 Cline  grok.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (93).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (40).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (25).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (75).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (49).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (72).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (80).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (47).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Grok 3.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (46).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (36).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (31).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (23).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Comprehensive Machine Catalog.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/(86).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/grok and Cline2.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (74).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (3).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (76).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (18).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (28).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (73).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/desktop.ini
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (37).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (52).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (5).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (81).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (15).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (63).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/The works Of Carl Dean Cline.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (39).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (4).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (66).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (90).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (55).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/grok and Cline 03272025.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (44).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (30).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/cline stuff.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Data grok and cline.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (89).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (69).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (13).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (82).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (59).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (51).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (16).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (29).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (42).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (78).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Comprehensive Machine Catalog2.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/Cline and XAI grok.txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (45).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (24).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (58).txt
# /kaggle/input/luft-and-tests/LUFT CLINE/New Text Document (7).txt
# /kaggle/input/luft-data-exchange/output
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_84416_HIP99427_0037.gpuspec.0000.h5
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_84066_HIP99560_0036.gpuspec.0000.h5
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_84766_HIP99759_0038.gpuspec.0000.h5
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_83371_HIP100670_0034.gpuspec.0000.h5
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_83716_HIP99427_0035.gpuspec.0000.h5
# /kaggle/input/listen-spliced-blc-files/HIP99427/spliced_blc0001020304050607_guppi_57752_83026_HIP99427_0033.gpuspec.0000.h5
# /kaggle/input/break-through-listen/breakthrough listen (89).txt
# /kaggle/input/l-u-f-t-unified-field-study/Carl Dean Cline Sr
# /kaggle/input/l-u-f-t-unified-field-study/LICENSE
# /kaggle/input/l-u-f-t-unified-field-study/.gitignore
# /kaggle/input/l-u-f-t-unified-field-study/README.md
# /kaggle/input/l-u-f-t-unified-field-study/Dr. Cline
# /kaggle/input/l-u-f-t-unified-field-study/.github/ISSUE_TEMPLATE/feature_request.md
# /kaggle/input/vygr-stock-performance/VYGR_stock_data.csv
# /kaggle/input/livecsv/Live.csv
# /kaggle/input/starlink-satellite-tlecsv-dataset-april-2025/starlink_csv.csv
# /kaggle/input/starlink-satellite-tlecsv-dataset-april-2025/starlink_tle.txt
# /kaggle/input/starlink-satellite-tlecsv-dataset-april-2025/starlink_44714_11_march2025_10_april_2025.txt
# /kaggle/input/starlink-satellite-tlecsv-dataset-april-2025/starlink_44714_11_march2025_10_april 2025.csv
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (99).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (103).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (100).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (96).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (98).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (102).txt
# /kaggle/input/chronological-construction-luft-inventions/New Text Document (97).txt
# /kaggle/input/voyagersquest/user.csv
# /kaggle/input/voyagersquest/track.csv
# /kaggle/input/voyagersquest/score.csv
